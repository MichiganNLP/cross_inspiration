# %%
# %%capture

# # This command installs several Python packages that are necessary for fine-tuning and optimizing language models:
# !pip install accelerate       # A PyTorch extension for distributed training and performance optimization.
# !pip install peft             # PEFT (Parameter-efficient Fine-tuning): Techniques for efficient fine-tuning of models.
# !pip install bitsandbytes     # Library for efficient training of deep learning models, focusing on memory and speed optimization.
# !pip install transformers     # Provides thousands of pre-trained models to perform tasks on texts such as classification, information extraction, and more.
# !pip install trl              # Token-level Reinforcement Learning for training language models.
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: accelerate in /home/oignat/.local/lib/python3.9/site-packages (0.31.0)
# Requirement already satisfied: huggingface-hub in /home/oignat/.local/lib/python3.9/site-packages (from accelerate) (0.23.3)
# Requirement already satisfied: psutil in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from accelerate) (5.8.0)
# Requirement already satisfied: packaging>=20.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from accelerate) (21.0)
# Requirement already satisfied: safetensors>=0.3.1 in /home/oignat/.local/lib/python3.9/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: pyyaml in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from accelerate) (6.0)
# Requirement already satisfied: numpy>=1.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from accelerate) (1.20.3)
# Requirement already satisfied: torch>=1.10.0 in /home/oignat/.local/lib/python3.9/site-packages (from accelerate) (2.3.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from packaging>=20.0->accelerate) (3.0.4)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (2.6.3)
# Requirement already satisfied: filelock in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (3.3.1)
# Requirement already satisfied: triton==2.3.1 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (2.3.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: jinja2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (2024.3.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: sympy in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (1.9)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/oignat/.local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.5.40)
# Requirement already satisfied: requests in /home/oignat/.local/lib/python3.9/site-packages (from huggingface-hub->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from huggingface-hub->accelerate) (4.62.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (2021.10.8)
# Requirement already satisfied: mpmath>=0.19 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from sympy->torch>=1.10.0->accelerate) (1.2.1)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: peft in /home/oignat/.local/lib/python3.9/site-packages (0.11.1)
# Requirement already satisfied: safetensors in /home/oignat/.local/lib/python3.9/site-packages (from peft) (0.4.3)
# Requirement already satisfied: accelerate>=0.21.0 in /home/oignat/.local/lib/python3.9/site-packages (from peft) (0.31.0)
# Requirement already satisfied: tqdm in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from peft) (4.62.3)
# Requirement already satisfied: transformers in /home/oignat/.local/lib/python3.9/site-packages (from peft) (4.41.2)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /home/oignat/.local/lib/python3.9/site-packages (from peft) (0.23.3)
# Requirement already satisfied: packaging>=20.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from peft) (21.0)
# Requirement already satisfied: pyyaml in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from peft) (6.0)
# Requirement already satisfied: torch>=1.13.0 in /home/oignat/.local/lib/python3.9/site-packages (from peft) (2.3.1)
# Requirement already satisfied: psutil in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from peft) (5.8.0)
# Requirement already satisfied: numpy>=1.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from peft) (1.20.3)
# Requirement already satisfied: requests in /home/oignat/.local/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (2.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/oignat/.local/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (2024.3.1)
# Requirement already satisfied: filelock in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (3.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/oignat/.local/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (4.12.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from packaging>=20.0->peft) (3.0.4)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (8.9.2.26)
# Requirement already satisfied: sympy in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.13.0->peft) (1.9)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: jinja2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.13.0->peft) (3.1.2)
# Requirement already satisfied: networkx in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.13.0->peft) (2.6.3)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (11.4.5.107)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (11.0.2.54)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.0.106)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.3.1)
# Requirement already satisfied: triton==2.3.1 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (2.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/oignat/.local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (1.26.7)
# Requirement already satisfied: mpmath>=0.19 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from sympy->torch>=1.13.0->peft) (1.2.1)
# Requirement already satisfied: regex!=2019.12.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers->peft) (2021.8.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/oignat/.local/lib/python3.9/site-packages (from transformers->peft) (0.19.1)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bitsandbytes in /home/oignat/.local/lib/python3.9/site-packages (0.43.1)
# Requirement already satisfied: numpy in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from bitsandbytes) (1.20.3)
# Requirement already satisfied: torch in /home/oignat/.local/lib/python3.9/site-packages (from bitsandbytes) (2.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: jinja2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch->bitsandbytes) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (4.12.2)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: sympy in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch->bitsandbytes) (1.9)
# Requirement already satisfied: networkx in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch->bitsandbytes) (2.6.3)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (2.20.5)
# Requirement already satisfied: filelock in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch->bitsandbytes) (3.3.1)
# Requirement already satisfied: fsspec in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (2.3.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/oignat/.local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from jinja2->torch->bitsandbytes) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from sympy->torch->bitsandbytes) (1.2.1)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/oignat/.local/lib/python3.9/site-packages (4.41.2)
# Requirement already satisfied: numpy>=1.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (1.20.3)
# Requirement already satisfied: tqdm>=4.27 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (4.62.3)
# Requirement already satisfied: pyyaml>=5.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (3.3.1)
# Requirement already satisfied: requests in /home/oignat/.local/lib/python3.9/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /home/oignat/.local/lib/python3.9/site-packages (from transformers) (0.23.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/oignat/.local/lib/python3.9/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/oignat/.local/lib/python3.9/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: regex!=2019.12.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (2021.8.3)
# Requirement already satisfied: packaging>=20.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (21.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/oignat/.local/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/oignat/.local/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: trl in /home/oignat/.local/lib/python3.9/site-packages (0.9.4)
# Requirement already satisfied: accelerate in /home/oignat/.local/lib/python3.9/site-packages (from trl) (0.31.0)
# Requirement already satisfied: tyro>=0.5.11 in /home/oignat/.local/lib/python3.9/site-packages (from trl) (0.8.4)
# Requirement already satisfied: transformers>=4.31.0 in /home/oignat/.local/lib/python3.9/site-packages (from trl) (4.41.2)
# Requirement already satisfied: torch>=1.4.0 in /home/oignat/.local/lib/python3.9/site-packages (from trl) (2.3.1)
# Requirement already satisfied: datasets in /home/oignat/.local/lib/python3.9/site-packages (from trl) (2.19.2)
# Requirement already satisfied: numpy>=1.18.2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from trl) (1.20.3)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (8.9.2.26)
# Requirement already satisfied: networkx in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.4.0->trl) (2.6.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (10.3.2.106)
# Requirement already satisfied: fsspec in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (2024.3.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (2.3.1)
# Requirement already satisfied: jinja2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.4.0->trl) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (4.12.2)
# Requirement already satisfied: filelock in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.4.0->trl) (3.3.1)
# Requirement already satisfied: sympy in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from torch>=1.4.0->trl) (1.9)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (12.1.3.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (2.20.5)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (11.0.2.54)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/oignat/.local/lib/python3.9/site-packages (from torch>=1.4.0->trl) (12.1.0.106)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/oignat/.local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl) (12.5.40)
# Requirement already satisfied: regex!=2019.12.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers>=4.31.0->trl) (2021.8.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /home/oignat/.local/lib/python3.9/site-packages (from transformers>=4.31.0->trl) (0.23.3)
# Requirement already satisfied: tqdm>=4.27 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers>=4.31.0->trl) (4.62.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/oignat/.local/lib/python3.9/site-packages (from transformers>=4.31.0->trl) (0.4.3)
# Requirement already satisfied: pyyaml>=5.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers>=4.31.0->trl) (6.0)
# Requirement already satisfied: requests in /home/oignat/.local/lib/python3.9/site-packages (from transformers>=4.31.0->trl) (2.32.3)
# Requirement already satisfied: packaging>=20.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers>=4.31.0->trl) (21.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/oignat/.local/lib/python3.9/site-packages (from transformers>=4.31.0->trl) (0.19.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from packaging>=20.0->transformers>=4.31.0->trl) (3.0.4)
# Requirement already satisfied: rich>=11.1.0 in /home/oignat/.local/lib/python3.9/site-packages (from tyro>=0.5.11->trl) (13.7.1)
# Requirement already satisfied: docstring-parser>=0.14.1 in /home/oignat/.local/lib/python3.9/site-packages (from tyro>=0.5.11->trl) (0.16)
# Requirement already satisfied: eval-type-backport>=0.1.3 in /home/oignat/.local/lib/python3.9/site-packages (from tyro>=0.5.11->trl) (0.2.0)
# Requirement already satisfied: shtab>=1.5.6 in /home/oignat/.local/lib/python3.9/site-packages (from tyro>=0.5.11->trl) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/oignat/.local/lib/python3.9/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/oignat/.local/lib/python3.9/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/oignat/.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Requirement already satisfied: psutil in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from accelerate->trl) (5.8.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/oignat/.local/lib/python3.9/site-packages (from datasets->trl) (0.3.8)
# Requirement already satisfied: xxhash in /home/oignat/.local/lib/python3.9/site-packages (from datasets->trl) (3.4.1)
# Requirement already satisfied: pandas in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from datasets->trl) (1.3.4)
# Requirement already satisfied: multiprocess in /home/oignat/.local/lib/python3.9/site-packages (from datasets->trl) (0.70.16)
# Requirement already satisfied: aiohttp in /home/oignat/.local/lib/python3.9/site-packages (from datasets->trl) (3.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/oignat/.local/lib/python3.9/site-packages (from datasets->trl) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /home/oignat/.local/lib/python3.9/site-packages (from datasets->trl) (0.6)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/oignat/.local/lib/python3.9/site-packages (from aiohttp->datasets->trl) (6.0.5)
# Requirement already satisfied: attrs>=17.3.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from aiohttp->datasets->trl) (21.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/oignat/.local/lib/python3.9/site-packages (from aiohttp->datasets->trl) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/oignat/.local/lib/python3.9/site-packages (from aiohttp->datasets->trl) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/oignat/.local/lib/python3.9/site-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/oignat/.local/lib/python3.9/site-packages (from aiohttp->datasets->trl) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers>=4.31.0->trl) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers>=4.31.0->trl) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers>=4.31.0->trl) (2021.10.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers>=4.31.0->trl) (1.26.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from jinja2->torch>=1.4.0->trl) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from pandas->datasets->trl) (2021.3)
# Requirement already satisfied: six>=1.5 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->datasets->trl) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from sympy->torch>=1.4.0->trl) (1.2.1)

# %%
# !which python
# Out:
# /sw/pkgs/arc/python3.9-anaconda/2021.11/bin/python
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# Importing essential modules and functions from various libraries:
import os                        # os module: Provides a way of using operating system dependent functionality.
import torch                     # PyTorch: A deep learning framework for tensor computation and automatic differentiation.

# datasets: A library from Hugging Face for loading and processing datasets.
from datasets import load_dataset

# AutoModelForCausalLM: Loads a model for causal language modeling (like GPT) from a pre-trained model.
# AutoTokenizer: Loads the tokenizer that corresponds to a pre-trained model.
# BitsAndBytesConfig: Configuration for bitsandbytes to optimize model training.
# TrainingArguments: Defines training parameters.
# pipeline: Simplifies the process of making predictions with models.
# logging: Used for logging events in the transformers library.
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline,
    logging,
)

# LoraConfig: Configuration for LoRA (Low-Rank Adaptation), a technique for parameter-efficient training.
from peft import LoraConfig

# SFTTrainer: Trainer class from the trl (Token-level Reinforcement Learning) library for model training.
from trl import SFTTrainer

# %%
from datasets import DatasetDict, Dataset
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Loading dataset

# %%
df = pd.read_csv('data/all_data.csv')

# %%
df = df.dropna()

# %% [markdown]
# > Check prompt if possible. Might have to finetune it a little bit. Think a bit about whether system prompt should come before <HUMAN> tag or after.

# %%
def create_prompt_and_response(row):
    label_text = "inspirational" if row['Label'] == 1 else "non-inspirational"
    prompt = f"<HUMAN>: Please classify the following text into its relevant country (india or uk), source of data (real or generated), and whether it is inspirational or not: {row['Text']}\n<ASSISTANT>: {row['Country']}, {row['Source']}, {label_text}"
    return prompt

# %%
# Apply the function to each row and add a new column
df['Prompt_Response'] = df.apply(create_prompt_and_response, axis=1)

# %%
df
# Out:
#                                                    Text Country     Source  \
# 0                                      Palaeontologist.      uk       real
# 1     \n> We have the capability of being better.  B...      uk       real
# 2     Only just noticed it myself, ha! Or Ha, accord...      uk       real
# 3     Mate all he does is play football and misses p...      uk       real
# 4     Me neither. But then, I'm not sure Cleese woul...      uk       real
# ...                                                 ...     ...        ...
# 5995  Often, I find my inspiration in the diverse an...   india  generated
# 5996  I often find inspiration in people overcoming ...   india  generated
# 5997  What inspires me most is the sheer determinati...   india  generated
# 5998  Just the other day, I watched a fascinating do...   india  generated
# 5999  The resilience of our local farmers truly insp...   india  generated
#
#       Label                                    Prompt_Response
# 0         0  <HUMAN>: Please classify the following text in...
# 1         1  <HUMAN>: Please classify the following text in...
# 2         0  <HUMAN>: Please classify the following text in...
# 3         1  <HUMAN>: Please classify the following text in...
# 4         0  <HUMAN>: Please classify the following text in...
# ...     ...                                                ...
# 5995      1  <HUMAN>: Please classify the following text in...
# 5996      1  <HUMAN>: Please classify the following text in...
# 5997      1  <HUMAN>: Please classify the following text in...
# 5998      1  <HUMAN>: Please classify the following text in...
# 5999      1  <HUMAN>: Please classify the following text in...
#
# [5999 rows x 5 columns]

# %%
df = df.drop(['Text', 'Country', 'Source', 'Label'], axis = 1)

# %%
df = df.rename(columns = {'Prompt_Response': 'Text'})

# %%
# Split the DataFrame into train and test sets
# df_train, df_test = train_test_split(df, test_size=0.2, random_state=42) #default split
df_train, df_test = train_test_split(df, test_size=0.9, random_state=42) # few-shot

# %%
# Convert DataFrame to Dataset
dataset = Dataset.from_pandas(df_train, preserve_index=False)

# Create a DatasetDict object with a single 'train' split
data = DatasetDict({'train': dataset})

# Print the summary of the dataset dict
print(data)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Text'],
#         num_rows: 599
#     })
# })

# %% [markdown]
# #Training

# %%
# Model from Hugging Face hub
base_model = "NousResearch/Llama-2-7b-chat-hf"
# base_model = "reecursion/Llama-2-7b-multicultural-inspiration" #default fine-tuned
# base_model = "reecursion/Llama-2-7b-multicultural-inspiration-fewshot" #few-shot fine-tuned

# %%
# Fine-tuned model name
new_model = "reecursion/Llama-2-7b-multicultural-inspiration-fewshot"

# %%
# Get the PyTorch data type for floating point 16-bit precision.
# This is typically used to reduce the memory and computation requirements
# without significantly impacting the model's performance accuracy.
compute_dtype = getattr(torch, "float16")

# Configure BitsAndBytes for quantization.
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,  # Enable loading model weights in 4-bit precision. This reduces the model's memory footprint further.
    bnb_4bit_quant_type="nf4",  # Set the quantization type to "nf4", which stands for "near-float 4-bit". This is a quantization scheme designed to maintain high accuracy with lower bit rates.
    bnb_4bit_compute_dtype=compute_dtype,  # Specify the data type for computation. Here it uses 16-bit floating points as defined above.
    bnb_4bit_use_double_quant=False,  # Determines whether to use double quantization. Setting this to False uses single quantization, which is simpler and faster.
)

# %%
# Load the pre-trained model from the Hugging Face Model Hub.
# The model is specified by the 'base_model' variable, which should contain the model identifier.
# 'quantization_config' applies the quantization settings defined earlier to optimize the model.
# 'device_map' specifies the mapping of model parts to devices. Here, it assigns the model to GPU 0.
# Note: Adjust this according to your hardware setup, especially if you don't have a GPU or have a different configuration.
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    quantization_config=quant_config,
    device_map={"": 0}
)

# Disable caching of past hidden states.
# This is useful for saving memory during training or inference, especially in generative tasks where caching is less beneficial.
model.config.use_cache = False

# Set 'pretraining_tp' to 1 in the model's configuration.
# This option might be specific to the model's architecture or training procedure.
# Since it's not a standard configuration option in Hugging Face's Transformers, it's likely specific to this model or a custom addition.
model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Load the tokenizer for the specified base model from Hugging Face's Model Hub.
# 'trust_remote_code=True' allows for the execution of custom tokenization logic from the remote model repository, if available.
# This can be important for models with custom tokenization processes.
tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)

# Set the padding token to be the same as the end-of-sequence (eos) token.
# This is common in models designed for generative tasks, where the eos token can also serve to pad sequences to a uniform length.
tokenizer.pad_token = tokenizer.eos_token

# Specify that padding should be added to the right of the sequences.
# This means if a batch of sequences is shorter than the longest sequence, padding tokens will be added to the end until they match the longest sequence's length.
tokenizer.padding_side = "right"

# %%
# Configure PEFT using LoRA for efficient fine-tuning of the model.
peft_params = LoraConfig(
    lora_alpha=16,    # The learning rate multiplier for LoRA parameters. This amplifies the updates applied to the adapted parameters.
    lora_dropout=0.1, # Dropout rate applied to the LoRA projections. Helps in preventing overfitting by randomly dropping units from the projections during training.
    r=2,              # Rank of the low-rank matrices in LoRA. A higher rank allows for more complex adaptations but increases the number of parameters to be trained.
    bias="none",       # Specifies how biases are handled in LoRA adaptations. "none" means that biases are not adapted as part of the LoRA process.
    task_type="CAUSAL_LM", # Indicates the type of task the model is being fine-tuned for. Here, it specifies a causal language modeling task.
)

# %%
training_params = TrainingArguments(
    output_dir="./results",  # Directory where the training results and model checkpoints will be saved.
    num_train_epochs=1,  # The total number of training epochs. One epoch means the model has seen the entire dataset once.
    per_device_train_batch_size=2,  # Batch size per device during training. Adjust based on your GPU memory.
    gradient_accumulation_steps=1,  # Number of steps to accumulate gradients before performing a backward/update pass.
    optim="paged_adamw_32bit",  # The optimizer to use. "paged_adamw_32bit" is an optimized version of AdamW for 32-bit precision.
    save_steps=1000,  # Save a checkpoint of the model every 25 steps.
    logging_steps=1000,  # Log training information every 25 steps.
    learning_rate=2e-4,  # The initial learning rate for AdamW.
    weight_decay=0.001,  # Weight decay rate to apply for regularization and prevent overfitting.
    fp16=False,  # Whether to use 16-bit (mixed) precision instead of 32-bit. False means 32-bit is used.
    bf16=False,  # Whether to use bfloat16 precision. False means it's not used, maintaining higher precision calculations.
    max_grad_norm=0.3,  # Maximum norm of the gradients for gradient clipping. Helps prevent the exploding gradient problem.
    max_steps=-1,  # If positive, set total number of training steps to perform. Overrides `num_train_epochs`. -1 means use `num_train_epochs`.
    warmup_ratio=0.03,  # Proportion of training to perform linear learning rate warmup. Helps stabilize the model's early training stages.
    group_by_length=True,  # Whether to group samples of similar lengths together. Improves training efficiency.
    lr_scheduler_type="constant",  # The learning rate scheduler type. "constant" means the learning rate does not change.
#     report_to="tensorboard"  # Logging the results to TensorBoard. Helps in monitoring the training process visually.
)

# %%
trainer = SFTTrainer(
    model=model,  # The pre-trained model you've loaded and possibly modified with quantization settings.
    train_dataset=dataset,  # The training dataset you've loaded, which the model will learn from.
    peft_config=peft_params,  # The PEFT (Parameter-efficient Fine-tuning) configuration, specifically for LoRA in this context.
    dataset_text_field="Text",  # The field in your dataset that contains the text data for training.
    max_seq_length=None,  # The maximum sequence length for model inputs. 'None' means the model's default or the dataset's max length is used.
    tokenizer=tokenizer,  # The tokenizer for processing text data to model-compatible inputs.
    args=training_params,  # The training arguments specifying how the model should be fine-tuned.
    packing=False,  # Whether to use data packing. Data packing can improve training efficiency but is set to 'False' here.
)
# Out:
# /home/oignat/.local/lib/python3.9/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /home/oignat/.local/lib/python3.9/site-packages/transformers/training_args.py:1965: FutureWarning: `--push_to_hub_token` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_token` instead.
#   warnings.warn(
# /home/oignat/.local/lib/python3.9/site-packages/transformers/training_args.py:1965: FutureWarning: `--push_to_hub_token` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_token` instead.
#   warnings.warn(
# /home/oignat/.local/lib/python3.9/site-packages/trl/trainer/sft_trainer.py:278: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# /home/oignat/.local/lib/python3.9/site-packages/trl/trainer/sft_trainer.py:307: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/599 [00:00<?, ? examples/s]
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.

# %%
# Train model
trainer.train()
# Out:
# {'train_runtime': 208.3539, 'train_samples_per_second': 2.875, 'train_steps_per_second': 1.44, 'train_loss': 1.3312919108072916, 'epoch': 1.0}
# TrainOutput(global_step=300, training_loss=1.3312919108072916, metrics={'train_runtime': 208.3539, 'train_samples_per_second': 2.875, 'train_steps_per_second': 1.44, 'train_loss': 1.3312919108072916, 'epoch': 1.0})

# %%
# Save the fine-tuned model to the specified directory. This will create the directory if it doesn't exist.
trainer.model.save_pretrained(new_model)

# Save the tokenizer to the same directory as the model. This ensures consistency between the model and tokenizer for future use.
trainer.tokenizer.save_pretrained(new_model)
# Out:
# /home/oignat/.local/lib/python3.9/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ('reecursion/Llama-2-7b-multicultural-inspiration-fewshot/tokenizer_config.json',
#  'reecursion/Llama-2-7b-multicultural-inspiration-fewshot/special_tokens_map.json',
#  'reecursion/Llama-2-7b-multicultural-inspiration-fewshot/tokenizer.json')

# %% [markdown]
# If it creates the directory locally, and we want to instead save it to huggingface

# %%
# from huggingface_hub import notebook_login
# notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# trainer.push_to_hub() #error login?

# %% [markdown]
# # Testing

# %%
logging.set_verbosity(logging.CRITICAL)

pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=1000)

# %%
gt = []
texts = []
data = list(df_test['Text'])   
for elem in data:
    input_, gt_data = elem.split("\n<ASSISTANT>:")
    texts.append(input_ + "\n<ASSISTANT>: ")
    gt.append(gt_data.strip())

# %%
predicted = pipe(texts)

# %%
import pickle
with open('predicted.pkl', 'wb') as f: 
    pickle.dump(predicted, f)
